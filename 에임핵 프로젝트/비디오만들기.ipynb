# %%
import cv2
import numpy as np
import math
import os
from PIL import ImageGrab
import os.path as osp
from ultralytics import YOLO, RTDETR
import pydirectinput
import time
import copy
# load model
#model = YOLO("runs/detect/by_yolov8x_imgsize160/weights/best.pt")
#model = RTDETR("runs/detect/by_RTDETR_imgsize160\weights/best.pt")
model = YOLO("train10 - yolo5s.pt")

# 화면 크기 설정
screen_size = (1280, 720)
#screen_size = (1920, 1080)

# 시야각
fov = 103
angrat=math.tan(math.radians(fov / 2))
# 중앙 300x300 영역 설정
center_size=300
center_half=center_size/2
center_x = (screen_size[0] - center_size) // 2
center_y = (screen_size[1] - center_size) // 2
bbox = (center_x, center_y, center_x + center_size, center_y + center_size)
# 저장 경로 디폴트셋팅
train_path = "images/"
label_path = "labels/"

# 이미지 저장할 폴더 생성
if not osp.isdir(train_path):
    os.makedirs(train_path)

# 텍스트 파일 저장할 폴더 생성
if not osp.isdir(label_path):
    os.makedirs(label_path)


# 파일 열기 함수
def open_file(filename, mode):
    try:
        return open(filename, mode)
    except FileNotFoundError:
        return open(filename, "w")

# 폴더 내 파일 개수 확인
def file_count(path):
    global count
    folder_path = path
    file_list = os.listdir(folder_path)
    count = len(file_list)
    return count

# 박스의 w/2,h/2 는 size의 크기와 같도록 함
size=5

count = file_count(train_path)

# 클릭 좌표 관련 변수
pointlist=[]
# 캐릭터별 번호
hero_num=1
# 라벨링 모드
menu=""
# 상태 관련 bool
while_rec=False
charic_select=False

# 마우스 이벤트
def mouse_callback(event, x, y, flags, param):
    global pointlist,  charic_select
    global menu, size, hero_num

    # 좌클릭시 pointlist에 현재 캐릭터, 좌표 추가
    if event == cv2.EVENT_LBUTTONDOWN and while_stop==True:
        point = [x,y,size,hero_num]
        pointlist.append(point)
        if charic_select==True:
            charic_select=False
            menu=""
    
    elif event == cv2.EVENT_MOUSEWHEEL:
        # 캐릭터 종류 변경
        if charic_select==True:
            if flags > 0:
                hero_num += 1
            else:
                hero_num -= 1
        else:
            # 마우스 휠에 따라 사각형 크기 조절
            if flags > 0:
                size += 1
            elif size > 1:
                size -= 1
        if hero_num>39:
                hero_num=1
        elif hero_num<1:
            hero_num=39

heroes={0: 'bot', 1: 'ana', 2: 'ashe', 3: 'baptiste', 4: 'bastion', 5: 'brigitte', 6: 'cassidy', 7: 'd.va', 8: 'doomfist', 9: 'echo',
        10: 'genji', 11: 'hanzo', 12: 'illari', 13: 'junkerqeen', 14: 'junkrat', 15: 'kiriko', 16: 'lifeweaver', 17: 'lucio', 18: 'mauga', 19: 'mei',
        20: 'mercy', 21: 'moira', 22: 'orisa', 23: 'pharah', 24: 'ramattra', 25: 'reaper', 26: 'reinhardt', 27: 'roadhog', 28: 'sigma', 29: 'sojourn', 
        30: 'soldier:76',  31: 'sombra', 32: 'symmetra', 33: 'torbjorn', 34: 'tracer', 35: 'widowmaker', 36: 'winston', 37: 'wreckingball', 38: 'zarya', 39: 'zenyatta'}

# %% [markdown]
# 녹화

# %%
# 녹화할 파일명과 코덱 설정
output_file = 'center_screen_recording_alone.avi'
fourcc = cv2.VideoWriter_fourcc(*'XVID')

# 비디오 녹화 객체 생성
out = cv2.VideoWriter(output_file, fourcc, 20.0, (center_size, center_size))
while True:
    # 현재 화면 캡쳐
    img = ImageGrab.grab(bbox=bbox)
    # 화면에 표시 및 파일에 저장
    img=np.array(img)
    cv2.imshow('Center Screen Recording', img)
    out.write(img)
    # 'q' 키를 누르면 종료
    if cv2.waitKey(1) == ord('q'):
        break
# 사용한 자원 해제
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# YOLO용 라벨링 함수(클래스, x, y, w, h)

# %%
# 마우스 클릭 좌표 기준 사각형 그리기
def stopped():
    global train_path, count
    global pointlist, while_stop, charic_select, menu
    while_stop=True

    while True:
        key=cv2.waitKey(10)
        tempimg=img.copy()

        # 상태바 & 박스 그리기
        #cv2.putText(tempimg, f"{menu}stop count:{count} tag : {heroes[hero_num]}", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
        cv2.putText(tempimg, f"tag : {heroes[hero_num]}", (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
        cv2.putText(tempimg, f"{menu}stop count:{count}", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
        if len(pointlist)>0:
            for point in pointlist:
                cv2.rectangle(tempimg, (point[0]-point[2], point[1]-point[2]), (point[0]+point[2], point[1]+point[2]), (255-point[3]*6, point[3]*6, -abs(6*(point[3]-20))+120))
        cv2.imshow("win",tempimg)

        if key == ord(" "):
            if  len(pointlist)>0:
                count = file_count(train_path)
                text = open_file(label_path + str(count) + ".txt", "w")
                cv2.imwrite(train_path + str(count) + '.jpg', img)
                for point in pointlist:
                    text.write(f"{point[3]} {float(point[0])/center_size} {float(point[1])/center_size} {float(point[2])*2/center_size} {float(point[2])*2/center_size}")
                    text.write("\n")
                text.close()
            break

        # 마지막 박스 지우기
        elif key == ord("x"):
            if len(pointlist)>0:
                pointlist.pop()
        # 캐릭터 변경 모드
        elif key == ord("z"):
            charic_select=True
            menu="change-"

    #변수 초기화
    while_stop=False
    pointlist=[]

# %% [markdown]
# 라벨링
#
# D: 60프레임 이후로 스킵
# A: 60프레임 이전으로 스킵
# Space: 화면 정지
# 좌클릭: 중앙점 생성, 정사각형 생성
# 횔업&다운: 정사각형 크기 늘리고 줄이고
# Z: 캐릭터 선택
# X: 최근에 선택한 박스 취소

# %%
readvideo=cv2.VideoCapture("center_screen_recording.avi")
cv2.namedWindow('win')
cv2.setMouseCallback("win", mouse_callback)
ret,img=readvideo.read()

while ret:
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    key = cv2.waitKey(33)
    
    # 프레임 조정
    if key == ord("d"):
        readvideo.set(cv2.CAP_PROP_POS_FRAMES, readvideo.get(cv2.CAP_PROP_POS_FRAMES) + 60)
    elif key == ord("a"):
        readvideo.set(cv2.CAP_PROP_POS_FRAMES, readvideo.get(cv2.CAP_PROP_POS_FRAMES) - 60)

    # 사각형 생성
    elif key == ord(" "):
        stopped()

    # 영상 종료
    elif key == ord("q"):
        break
    
    ret,img=readvideo.read()

    cv2.imshow("win", img)

readvideo.release()
cv2.destroyAllWindows()

# %% [markdown]
# YOLO 라벨링 확인용

# %%
cv2.namedWindow('win')
cv2.setMouseCallback("win", mouse_callback)

# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./imgNlabel/train/images"
lth = "./imgNlabel/train/labels"

# 이미지 목록과 레이블 목록을 생성
img_list = sorted(os.listdir(pth))
lab_list = sorted(os.listdir(lth))

# 이미지와 레이블을 읽음
for i in img_list:

    key=""
    num=i.find(".")

    img = cv2.imread(pth + '/' + i[:num] + ".jpg")
    img = cv2.resize(img, (center_size,center_size))
    with open(lth + '/' + i[:num] + ".txt","r") as lbr:
            ll=lbr.read()
            ll=list(ll.split())

    for j in range(len(ll)):
        if j==0:
            ll[j]=int(float(ll[j]))
        else:
            ll[j]=round(center_size*float(ll[j]))

    hero_num=ll[0]
    size=round(ll[3]//2)

    while key!=ord(" "):

        img_temp=img.copy()


        cv2.rectangle(img_temp, (ll[1]-size, ll[2]-size), (ll[1]+size, ll[2]+size), (0, 0, 255) if charic_select==True else (255,255,255), 1)
        cv2.putText(img_temp, f" hero : {heroes[hero_num]}", (10, ll[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
        # 텍스트 추가
        cv2.putText(img_temp, str(i), (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
        
        # 이미지 출력
        cv2.imshow("win", img_temp)
        key=cv2.waitKey(0)

        if key == ord("q"):
            break
        elif key == ord("a"):
            with open(lth + '/' + i[:num] + ".txt","w") as lbr:
                lbr.write(f"{hero_num} {float(ll[1])/center_size} {float(ll[2])/center_size} {float(size*2)/center_size} {float(size*2)/center_size}")
            break

        elif key ==ord("w"):
            size-=1
        elif key ==ord("e"):
            size+=1
        elif key ==ord("s"):
            hero_num-=1
        elif key ==ord("d"):
            hero_num+=1
        if size<0:
            size=1
        if hero_num>39:
            hero_num=0
        elif hero_num ==-1:
            hero_num=39
    
    if key==ord('q'):
        break

# 모든 창 닫음
cv2.destroyAllWindows()

# %% [markdown]
# yolo모델 결과 확인

# %%
readvideo=cv2.VideoCapture("center_screen_recording.avi")
ret,image=readvideo.read()

while ret:
    img = ImageGrab.grab(bbox=bbox)
    results=model(img)
    for r in results:
        if len(r.boxes.xywh)>0:
                result = r.boxes.xywh[0].cpu().numpy()
                result = result.tolist()
                x, y, w, h= result
    
    cv2.rectangle(img, (x-round(w/2), y-round(h/2)), (x+round(w/2), y+round(h/2)), (0,0,255), 2)
    ret,img=readvideo.read()
    if key == ord("q"):
        break
    
readvideo.release()
cv2.destroyAllWindows()

# %% [markdown]
# 마우스 이동(YOLO)

# %%
# 비디오 캡쳐
while True:
    img = ImageGrab.grab(bbox=bbox)
    results=model(img)
    for r in results:
        if len(r.boxes.xywh)>0:
                result = r.boxes.xywh[0].cpu().numpy()
                result = result.tolist()
                x, y, w, h= result
                #디폴트
                #pydirectinput.moveRel(round(x-150), round(y-150), relative=True)
                #제곱
                #pydirectinput.moveRel(round((x-150)*abs(x-150)/80), round((y-150)*abs(x-150)/80), relative=True)
                #아크탄젠트
                #pydirectinput.moveRel(round(math.atan(x-150)*abs(x-150)), round(math.atan(y-150)*abs(y-150)), relative=True)
                #시야각형식+속도 고려
                #pydirectinput.moveRel(round((x-center_half)*max(abs(math.atan(x-center_half)),1) / angrat), round((y-center_half)*max(abs(math.atan(y-center_half)),1) / angrat), relative=True)
                L=(640/math.tan(math.radians(103/2)))
                xx=math.atan((x-center_half)/L)
                yy=math.atan((y-center_half)/L)
                print(xx,yy)
                pydirectinput.moveRel(round(xx*L),round((yy*L)), relative=True)
# Out:
# 0: 160x160 8 enemys, 52.7ms
# Speed: 5.0ms preprocess, 52.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# -0.010077529392643806 0.0699457740517247
#
# 0: 160x160 9 enemys, 44.2ms
# Speed: 1.0ms preprocess, 44.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 38.3ms
# Speed: 1.0ms preprocess, 38.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 44.7ms
# Speed: 0.5ms preprocess, 44.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 50.5ms
# Speed: 0.0ms preprocess, 50.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.01006751931830347 0.06995943476823013
#
# 0: 160x160 9 enemys, 44.9ms
# Speed: 0.0ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.01006784899144263 0.06995633277376402
#
# 0: 160x160 9 enemys, 38.5ms
# Speed: 1.0ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.010070156703355456 0.06995558710181632
#
# 0: 160x160 8 enemys, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.010076660254532617 0.06995758550246074
#
# 0: 160x160 8 enemys, 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.01006745937773248 0.06995484142979069
#
# 0: 160x160 9 enemys, 34.4ms
# Speed: 0.0ms preprocess, 34.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 32.2ms
# Speed: 1.4ms preprocess, 32.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 9 enemys, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0100700068519358 0.06995558710181632
#
# 0: 160x160 (no detections), 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 38.6ms
# Speed: 0.0ms preprocess, 38.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 36.6ms
# Speed: 0.0ms preprocess, 36.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.5ms
# Speed: 0.0ms preprocess, 33.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.8ms
# Speed: 0.0ms preprocess, 33.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.3ms
# Speed: 0.0ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.9ms
# Speed: 1.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.2ms
# Speed: 1.1ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 5 enemys, 27.3ms
# Speed: 1.0ms preprocess, 27.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.14412021220504692 0.14656737350928403
#
# 0: 160x160 5 enemys, 42.6ms
# Speed: 1.1ms preprocess, 42.6ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# 0.14412021220504692 0.14656737350928403
#
# 0: 160x160 4 enemys, 59.6ms
# Speed: 0.0ms preprocess, 59.6ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
# 0.144103597202847 0.146567608181548
#
# 0: 160x160 (no detections), 50.5ms
# Speed: 2.1ms preprocess, 50.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 49.0ms
# Speed: 0.0ms preprocess, 49.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.0ms
# Speed: 1.5ms preprocess, 46.0ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 38.2ms
# Speed: 1.3ms preprocess, 38.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 48.7ms
# Speed: 1.0ms preprocess, 48.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 57.5ms
# Speed: 1.2ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.07604630409867402 -0.2154965604796483
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 1.3ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.09763480259199192 0.028500747571709215
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# 0.056457486907911095 0.0403572376592522
#
# 0: 160x160 1 enemy, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.05316625579731248 -0.0092277450166247
#
# 0: 160x160 1 enemy, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.03286284569845504 0.006139178846850435
#
# 0: 160x160 1 enemy, 49.4ms
# Speed: 0.0ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.006449929947801429 -0.004714469096325517
#
# 0: 160x160 1 enemy, 42.3ms
# Speed: 1.1ms preprocess, 42.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.002638125905068592 -0.0009516827014014929
#
# 0: 160x160 1 enemy, 41.5ms
# Speed: 0.0ms preprocess, 41.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.002066717646976209 -0.0012506062901892086
#
# 0: 160x160 2 enemys, 43.0ms
# Speed: 0.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.20691487411300533 -0.010923523025820956
#
# 0: 160x160 1 enemy, 42.4ms
# Speed: 1.0ms preprocess, 42.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.20737930694651224 0.018911961059934347
#
# 0: 160x160 2 enemys, 45.9ms
# Speed: 1.4ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.11800831876807867 -0.00013251206161949967
#
# 0: 160x160 2 enemys, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.09773770192226268 -0.03651578723703583
#
# 0: 160x160 2 enemys, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# 0.07369303208120508 -0.03517665301711788
#
# 0: 160x160 1 enemy, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.06569950972048921 0.02800110161627599
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.052200413572619724 0.0027370071843944585
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.004718305596368835 0.005931141587998955
#
# 0: 160x160 1 enemy, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0022102892088465367 -0.008392153669064742
#
# 0: 160x160 1 enemy, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.0024947944172887633 0.0004979767524657782
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0036058950600118883 0.0010257766841798598
#
# 0: 160x160 1 enemy, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0026317116584112787 -0.0012127200669912442
#
# 0: 160x160 1 enemy, 56.4ms
# Speed: 1.0ms preprocess, 56.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.0006566554728991281 0.0015733583894210468
#
# 0: 160x160 1 enemy, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.004152540290917817 0.0010283244139745774
#
# 0: 160x160 1 enemy, 45.9ms
# Speed: 1.5ms preprocess, 45.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.02348349770904193 -0.01207191884728378
#
# 0: 160x160 1 enemy, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.004959315444899792 -0.00146425574432225
#
# 0: 160x160 1 enemy, 46.9ms
# Speed: 0.0ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0007444772670661979 0.012900222335563073
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 0.0ms preprocess, 44.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.044993950345804896 -0.02484220394484765
#
# 0: 160x160 1 enemy, 45.6ms
# Speed: 1.5ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.06995406593080138 -0.002342830557443211
#
# 0: 160x160 1 enemy, 45.2ms
# Speed: 0.0ms preprocess, 45.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.08331816084572609 0.04227869003028138
#
# 0: 160x160 1 enemy, 45.9ms
# Speed: 1.0ms preprocess, 45.9ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.10158345868994599 0.03488941180547738
#
# 0: 160x160 1 enemy, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# -0.16405217094346536 -0.027556281250519867
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.1880965297722634 0.0074240759459112664
#
# 0: 160x160 1 enemy, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.2083259039876501 -0.008526454519653129
#
# 0: 160x160 1 enemy, 45.6ms
# Speed: 0.5ms preprocess, 45.6ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.22644010174902118 0.008116507797944152
#
# 0: 160x160 3 enemys, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.2177955655667101 0.005240877518468392
#
# 0: 160x160 2 enemys, 43.7ms
# Speed: 1.2ms preprocess, 43.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.1901405768814324 5.515091485179866e-05
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.12255278079928064 0.017211859827246913
#
# 0: 160x160 1 enemy, 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.09022302093339632 -0.02220448450063456
#
# 0: 160x160 1 enemy, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# -0.063128665227422 -0.050230797235985045
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.05471839487843798 0.013589967299855836
#
# 0: 160x160 1 enemy, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.048418142134790336 0.009018368808064323
#
# 0: 160x160 1 enemy, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# -0.04156753546560351 0.008746352389521081
#
# 0: 160x160 1 enemy, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.03068257148132147 0.006243272208511658
#
# 0: 160x160 1 enemy, 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.02328692030315227 0.007913211806451593
#
# 0: 160x160 1 enemy, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.021525493840874745 0.002173422198286056
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.01779391326717464 0.00982655764316398
#
# 0: 160x160 1 enemy, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.016823218399675034 -0.0026733742846802764
#
# 0: 160x160 1 enemy, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.011485452272458426 0.009272101739704417
#
# 0: 160x160 1 enemy, 52.5ms
# Speed: 1.0ms preprocess, 52.5ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.014047752348713116 -0.003139005921314686
#
# 0: 160x160 1 enemy, 43.2ms
# Speed: 1.5ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.01030812018265667 0.009722110590747906
#
# 0: 160x160 1 enemy, 40.3ms
# Speed: 0.0ms preprocess, 40.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.0034114005599708607 -0.0036241186024372576
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0004608997600464726 -0.004996421499692367
#
# 0: 160x160 (no detections), 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.001246110298697858 0.004435962807784293
#
# 0: 160x160 1 enemy, 42.1ms
# Speed: 0.0ms preprocess, 42.1ms inference, 2.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.008748270535438222 0.002237594771337305
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 0.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.007087193530527469 -0.003479978709479268
#
# 0: 160x160 2 enemys, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.00828467680486824 0.00221922121538277
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.006191929890548167 0.0018848702047893897
#
# 0: 160x160 1 enemy, 47.6ms
# Speed: 0.0ms preprocess, 47.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004207030840704932 -0.008704932410445782
#
# 0: 160x160 1 enemy, 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 2.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.001283576892902518 0.009254478937866606
#
# 0: 160x160 1 enemy, 43.8ms
# Speed: 0.0ms preprocess, 43.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.012474789534603604 -0.00520392141875866
#
# 0: 160x160 1 enemy, 45.2ms
# Speed: 1.1ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.011194688486276595 -0.000421784580738599
#
# 0: 160x160 1 enemy, 44.2ms
# Speed: 1.5ms preprocess, 44.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.012604403774906299 -0.0019896265765504753
#
# 0: 160x160 1 enemy, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.01338115116369692 -0.005617061607254699
#
# 0: 160x160 1 enemy, 45.7ms
# Speed: 1.1ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.016755497781847047 -0.0012619961350739328
#
# 0: 160x160 1 enemy, 42.3ms
# Speed: 1.2ms preprocess, 42.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# 0.018847721158412243 -0.008164312080677858
#
# 0: 160x160 1 enemy, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.02253103029112979 -0.0015896038900284034
#
# 0: 160x160 1 enemy, 43.6ms
# Speed: 0.0ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.024761116058098675 -0.009379816494736274
#
# 0: 160x160 1 enemy, 43.9ms
# Speed: 0.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.032722990809865585 -0.0034518640699404486
#
# 0: 160x160 1 enemy, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.034207703623439285 -0.007947708931897671
#
# 0: 160x160 1 enemy, 43.6ms
# Speed: 1.3ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.04737064317095735 -0.010230737223355497
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.06282722333790176 -0.006564543082719213
#
# 0: 160x160 1 enemy, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.06936854020767788 0.045436350109871
#
# 0: 160x160 1 enemy, 44.7ms
# Speed: 1.2ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.08930351485249167 0.020658242031271513
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.1ms preprocess, 45.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# 0.123204412979932 -0.01975701264253246
#
# 0: 160x160 1 enemy, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.15434555131202232 -0.005762637325333602
#
# 0: 160x160 1 enemy, 50.7ms
# Speed: 1.1ms preprocess, 50.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.18499187408482642 -0.001050624542427828
#
# 0: 160x160 2 enemys, 43.9ms
# Speed: 0.0ms preprocess, 43.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.2237708243466937 -0.006927743280805302
#
# 0: 160x160 2 enemys, 46.5ms
# Speed: 0.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.21261831431728065 0.009236646334917442
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.20636387736323974 -0.006762777839754277
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.15382172487534412 0.023542542473638545
#
# 0: 160x160 1 enemy, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.12630524138454954 -0.008006093250499976
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 1.5ms preprocess, 45.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# 0.08402951945996025 -0.05945790392340975
#
# 0: 160x160 1 enemy, 45.7ms
# Speed: 1.3ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.06467704103210728 -0.0012833371067109537
#
# 0: 160x160 1 enemy, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.06052389601928603 0.017154088320564222
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.03628607659696287 0.007762904824799205
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.006174456111125786 -0.007275326378010841
#
# 0: 160x160 1 enemy, 47.1ms
# Speed: 1.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0017917134307869943 0.0005187182868420962
#
# 0: 160x160 1 enemy, 44.4ms
# Speed: 1.5ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0023354271870912164 9.552498112840445e-05
#
# 0: 160x160 1 enemy, 56.6ms
# Speed: 1.0ms preprocess, 56.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# -0.003802457416666311 0.000976830296283141
#
# 0: 160x160 1 enemy, 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.002531511506447087 0.0019332769455189924
#
# 0: 160x160 1 enemy, 44.8ms
# Speed: 0.0ms preprocess, 44.8ms inference, 2.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.0002041782756145086 -0.002845629661665272
#
# 0: 160x160 1 enemy, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.007249970283965087 0.005010958197541925
#
# 0: 160x160 1 enemy, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.01114050347598466 -0.01880799061903071
#
# 0: 160x160 1 enemy, 47.3ms
# Speed: 1.4ms preprocess, 47.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.019092095621121196 0.007618052320866006
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
# -0.02855929773528942 0.007483359885605865
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.04028104956637321 -0.01671594407551383
#
# 0: 160x160 1 enemy, 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.07013084769145358 0.003274214192334522
#
# 0: 160x160 2 enemys, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.07863299262548355 0.051329628266092435
#
# 0: 160x160 1 enemy, 50.7ms
# Speed: 1.0ms preprocess, 50.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.13302054759973744 0.018463536951160493
#
# 0: 160x160 2 enemys, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.1706923361646837 -0.02475194984130444
#
# 0: 160x160 2 enemys, 53.6ms
# Speed: 0.0ms preprocess, 53.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.19380806837824452 0.009321253741573682
#
# 0: 160x160 1 enemy, 44.3ms
# Speed: 1.1ms preprocess, 44.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.2059547986785304 -0.018900785006179435
#
# 0: 160x160 1 enemy, 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.20943232885666307 0.01646720400573978
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 1.3ms preprocess, 45.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.268162204841619 -0.15131234118028175
#
# 0: 160x160 (no detections), 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 65.2ms
# Speed: 1.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.8ms
# Speed: 1.5ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.0ms
# Speed: 1.2ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.6ms
# Speed: 1.0ms preprocess, 42.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.5ms
# Speed: 0.0ms preprocess, 42.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 44.4ms
# Speed: 0.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.4ms
# Speed: 1.1ms preprocess, 41.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.17443408304099106 0.03601571118754717
#
# 0: 160x160 1 enemy, 44.7ms
# Speed: 0.0ms preprocess, 44.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.14053751844153137 0.00437272032240922
#
# 0: 160x160 1 enemy, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.03723716242790332 0.007101969635171739
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.044234291884836956 0.0038993297609877372
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 0.0ms preprocess, 44.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.03458704641380188 0.010017229153852001
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 1.3ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0337521559404615 0.0006094475075986193
#
# 0: 160x160 1 enemy, 46.6ms
# Speed: 0.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.018607509294182693 0.006115740588045058
#
# 0: 160x160 1 enemy, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.1067500389769674 0.0007613222652225817
#
# 0: 160x160 1 enemy, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.044875465570602 -0.014394323730103062
#
# 0: 160x160 1 enemy, 45.6ms
# Speed: 1.4ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.010391886647365517 0.008490818818268882
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 0.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0038400434152700332 0.02729136654062458
#
# 0: 160x160 1 enemy, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0028774910434518795 -0.01732170927319771
#
# 0: 160x160 1 enemy, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0024119186771856594 -0.011225197495244024
#
# 0: 160x160 1 enemy, 48.2ms
# Speed: 0.0ms preprocess, 48.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0009284533963583925 -0.004604559306117866
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004042599987020239 0.005223763219403164
#
# 0: 160x160 1 enemy, 47.2ms
# Speed: 1.0ms preprocess, 47.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.003089580390543558 0.011974729410925936
#
# 0: 160x160 1 enemy, 46.9ms
# Speed: 1.0ms preprocess, 46.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004426551369067869 0.0030430622301418904
#
# 0: 160x160 1 enemy, 52.9ms
# Speed: 1.0ms preprocess, 52.9ms inference, 2.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.0005425770454848988 -0.01934893204122412
#
# 0: 160x160 1 enemy, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.013063609355205627 -0.020047668689815605
#
# 0: 160x160 1 enemy, 43.2ms
# Speed: 1.0ms preprocess, 43.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0250588960115852 0.003327536153518705
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.009203288861872222 -0.034453105501120455
#
# 0: 160x160 1 enemy, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.016437748203571433 0.029907603581079113
#
# 0: 160x160 1 enemy, 47.3ms
# Speed: 0.0ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.025340616139684562 -0.011624449985594743
#
# 0: 160x160 1 enemy, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.017388529653822937 0.019131496146310906
#
# 0: 160x160 1 enemy, 44.1ms
# Speed: 1.0ms preprocess, 44.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.037079540743172795 -0.04251693881899668
#
# 0: 160x160 2 enemys, 47.1ms
# Speed: 1.0ms preprocess, 47.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.048749493178244285 -0.02736309905502468
#
# 0: 160x160 1 enemy, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.08306240821914859 -0.05596353194103357
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.17778232696858426 -0.027927275136437568
#
# 0: 160x160 1 enemy, 45.8ms
# Speed: 1.0ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.05252102681893948 -0.07094982635829268
#
# 0: 160x160 1 enemy, 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0003000629307449502 -0.011913172987197016
#
# 0: 160x160 1 enemy, 43.3ms
# Speed: 1.0ms preprocess, 43.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.022173297630861146 0.01294778205488538
#
# 0: 160x160 (no detections), 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.9ms
# Speed: 0.0ms preprocess, 40.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 61.4ms
# Speed: 1.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# -0.009129650594250445 0.2700624231958714
#
# 0: 160x160 1 enemy, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.13113844184400109 -0.060580188827771546
#
# 0: 160x160 1 enemy, 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.04379405840993602 -0.025347086219938964
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.03063927078797307 -0.005737580455532284
#
# 0: 160x160 1 enemy, 46.6ms
# Speed: 1.1ms preprocess, 46.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.023157355575175873 0.0036885004402024473
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.03267116243638046 -0.0115337928386546
#
# 0: 160x160 1 enemy, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.03721716798308568 0.005047015193568964
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.05375525346394461 -0.016632491576678916
#
# 0: 160x160 1 enemy, 43.4ms
# Speed: 0.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.06775131231502449 -0.073886054534948
#
# 0: 160x160 1 enemy, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.09446024375137485 -0.09159575105646875
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 1.0ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.1609305121019599 -0.045564086372980664
#
# 0: 160x160 1 enemy, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.19318542808814393 -0.049838770097948966
#
# 0: 160x160 2 enemys, 45.8ms
# Speed: 0.0ms preprocess, 45.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.05834171217354188 -0.016832897041757607
#
# 0: 160x160 1 enemy, 46.2ms
# Speed: 1.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.016919105736045336 -0.014369930491251775
#
# 0: 160x160 2 enemys, 57.4ms
# Speed: 1.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.03077704804390604 0.007933412558134626
#
# 0: 160x160 1 enemy, 46.0ms
# Speed: 1.0ms preprocess, 46.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004806754867217097 -0.012909962043397073
#
# 0: 160x160 2 enemys, 47.6ms
# Speed: 1.0ms preprocess, 47.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.0008556482519827689 0.014832260336152451
#
# 0: 160x160 1 enemy, 44.5ms
# Speed: 1.0ms preprocess, 44.5ms inference, 2.3ms postprocess per image at shape (1, 3, 160, 160)
# 0.007289862668843858 -0.009177184302189468
#
# 0: 160x160 1 enemy, 46.5ms
# Speed: 1.0ms preprocess, 46.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.012515636796121084 0.015962166431005106
#
# 0: 160x160 2 enemys, 51.3ms
# Speed: 1.0ms preprocess, 51.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.133805571132729 0.020616776617220507
#
# 0: 160x160 1 enemy, 45.1ms
# Speed: 1.0ms preprocess, 45.1ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.019071002083642936 -0.01039353500209904
#
# 0: 160x160 1 enemy, 45.2ms
# Speed: 1.0ms preprocess, 45.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.02443688108657219 0.07539266121559744
#
# 0: 160x160 1 enemy, 47.4ms
# Speed: 0.0ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.13837666623300243 -0.0002933189335917523
#
# 0: 160x160 2 enemys, 45.2ms
# Speed: 0.0ms preprocess, 45.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.11756009452289379 0.06910541094458178
#
# 0: 160x160 2 enemys, 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.07916859474910987 0.086410488012362
#
# 0: 160x160 1 enemy, 51.8ms
# Speed: 1.0ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.05230853132596716 0.04864863273796721
#
# 0: 160x160 1 enemy, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0468983851850333 -0.008148936788786873
#
# 0: 160x160 1 enemy, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.036921677755270096 0.015705868866730015
#
# 0: 160x160 1 enemy, 45.9ms
# Speed: 1.3ms preprocess, 45.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.024679398789177836 -0.0033564900604531435
#
# 0: 160x160 1 enemy, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.020371248385709084 0.006640312341001014
#
# 0: 160x160 1 enemy, 46.3ms
# Speed: 1.0ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.020694224605400213 0.004069335751588006
#
# 0: 160x160 1 enemy, 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.014396001888411742 -0.002144737861587429
#
# 0: 160x160 1 enemy, 41.8ms
# Speed: 1.0ms preprocess, 41.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.013935674063825848 0.0043772162348526995
#
# 0: 160x160 1 enemy, 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.012944635383391518 -0.008610643403354575
#
# 0: 160x160 1 enemy, 47.0ms
# Speed: 1.5ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.008870791971898521 -0.025671066772280052
#
# 0: 160x160 1 enemy, 43.1ms
# Speed: 1.5ms preprocess, 43.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.008766492918438304 -0.0013837475611829606
#
# 0: 160x160 1 enemy, 47.5ms
# Speed: 1.0ms preprocess, 47.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0076910031153081615 0.006253732489930462
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.005964740494746606 0.000980127358691595
#
# 0: 160x160 1 enemy, 46.3ms
# Speed: 0.0ms preprocess, 46.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# -0.0056781752641861145 0.005292010589816068
#
# 0: 160x160 1 enemy, 50.0ms
# Speed: 1.1ms preprocess, 50.0ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0055463867128645785 -0.00029439797313807284
#
# 0: 160x160 1 enemy, 46.8ms
# Speed: 0.0ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.00299681381405759 -0.0008392528559021461
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.000667026238224809 0.0070132530173151065
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0075597875360467375 -0.004592060694573887
#
# 0: 160x160 1 enemy, 42.8ms
# Speed: 1.5ms preprocess, 42.8ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0021817547426566572 0.004777711383930908
#
# 0: 160x160 1 enemy, 43.4ms
# Speed: 0.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0035352188647039206 -0.0019490428541769783
#
# 0: 160x160 1 enemy, 45.6ms
# Speed: 1.0ms preprocess, 45.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0032520341692531735 0.005240667710967772
#
# 0: 160x160 1 enemy, 44.8ms
# Speed: 1.0ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0016668149661688294 -0.001969364689381693
#
# 0: 160x160 1 enemy, 44.6ms
# Speed: 1.0ms preprocess, 44.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.005604832876342433 -0.0007960613258818674
#
# 0: 160x160 1 enemy, 47.7ms
# Speed: 0.0ms preprocess, 47.7ms inference, 2.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.003293247047411176 -0.0023059036226231126
#
# 0: 160x160 1 enemy, 48.6ms
# Speed: 1.0ms preprocess, 48.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.0012359193844645715 -0.000489284490821258
#
# 0: 160x160 1 enemy, 44.3ms
# Speed: 1.0ms preprocess, 44.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.0025893896143155556 -0.0011275359988030906
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 1.0ms preprocess, 45.4ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.004108120583558125 0.002684344442289689
#
# 0: 160x160 1 enemy, 44.0ms
# Speed: 0.0ms preprocess, 44.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0038924959469965525 0.0012444917417486299
#
# 0: 160x160 1 enemy, 46.4ms
# Speed: 0.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.002595504131178185 -0.001952939371376887
#
# 0: 160x160 1 enemy, 49.6ms
# Speed: 1.0ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0033198930405069853 -0.0006104366269001783
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.0014003527501238952 -0.00416770653003768
#
# 0: 160x160 1 enemy, 43.8ms
# Speed: 1.0ms preprocess, 43.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.003969945817454019 0.007946330246099713
#
# 0: 160x160 1 enemy, 46.8ms
# Speed: 1.0ms preprocess, 46.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.006144423980570855 -0.006425322869177602
#
# 0: 160x160 1 enemy, 44.9ms
# Speed: 1.0ms preprocess, 44.9ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.0022497339061725474 0.003285004472670072
#
# 0: 160x160 1 enemy, 42.0ms
# Speed: 1.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.00332669690975601 -0.00749828576306012
#
# 0: 160x160 1 enemy, 48.8ms
# Speed: 1.0ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0046806599337060086 0.0027842447819348684
#
# 0: 160x160 1 enemy, 45.1ms
# Speed: 0.0ms preprocess, 45.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004960814074195518 -0.0023489450817508416
#
# 0: 160x160 1 enemy, 47.3ms
# Speed: 1.0ms preprocess, 47.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.004565984450047415 -0.0011349693734735299
#
# 0: 160x160 1 enemy, 44.1ms
# Speed: 0.0ms preprocess, 44.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.003599780581424059 -0.0005547162377750537
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.5ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.0027058651321139747 -0.006453826317635305
#
# 0: 160x160 1 enemy, 45.4ms
# Speed: 0.0ms preprocess, 45.4ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.010220727180146032 0.0010560796812191897
#
# 0: 160x160 1 enemy, 47.0ms
# Speed: 1.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.005591045579676211 -0.009497361396319555
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 0.0ms preprocess, 45.3ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.00930521940443885 0.0030040972660528046
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 1.5ms preprocess, 45.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.00907429445237654 0.0022288426045776197
#
# 0: 160x160 1 enemy, 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.010794533053931651 0.03195249361291988
#
# 0: 160x160 1 enemy, 45.8ms
# Speed: 1.5ms preprocess, 45.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.008234085286493425 -0.0028599268205325634
#
# 0: 160x160 1 enemy, 44.0ms
# Speed: 1.0ms preprocess, 44.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.014138733285267487 -0.007413286143374684
#
# 0: 160x160 1 enemy, 55.2ms
# Speed: 0.0ms preprocess, 55.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.015823305130328532 0.005499689699613798
#
# 0: 160x160 1 enemy, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# 0.028740068255894178 -0.011351578893653532
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.02851494338381131 0.004280584051395607
#
# 0: 160x160 1 enemy, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# 0.03578263952279288 -0.012150857000634013
#
# 0: 160x160 2 enemys, 46.6ms
# Speed: 1.0ms preprocess, 46.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.05892549917762287 -0.004494709350097268
#
# 0: 160x160 1 enemy, 44.1ms
# Speed: 0.0ms preprocess, 44.1ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.07496249658420379 -0.008686739978928165
#
# 0: 160x160 1 enemy, 46.2ms
# Speed: 0.0ms preprocess, 46.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.10291532837397185 -0.07873737023438993
#
# 0: 160x160 1 enemy, 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.15320937403334262 -0.13845796473168584
#
# 0: 160x160 1 enemy, 43.0ms
# Speed: 1.0ms preprocess, 43.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.19881790441230526 -0.08404792734008006
#
# 0: 160x160 (no detections), 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.5ms
# Speed: 1.5ms preprocess, 42.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.0ms
# Speed: 0.0ms preprocess, 42.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.8ms
# Speed: 0.0ms preprocess, 41.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.9ms
# Speed: 1.0ms preprocess, 41.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 47.0ms
# Speed: 0.0ms preprocess, 47.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 43.5ms
# Speed: 1.0ms preprocess, 43.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.7ms
# Speed: 0.0ms preprocess, 42.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 53.1ms
# Speed: 0.0ms preprocess, 53.1ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.9ms
# Speed: 1.1ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.5ms
# Speed: 0.0ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.6ms
# Speed: 0.0ms preprocess, 41.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.0ms
# Speed: 1.0ms preprocess, 40.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 41.7ms
# Speed: 1.2ms preprocess, 41.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.2638160320061594 -0.013897735185256551
#
# 0: 160x160 1 enemy, 47.5ms
# Speed: 0.5ms preprocess, 47.5ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.1496459495627187 -0.060112454129888686
#
# 0: 160x160 (no detections), 48.3ms
# Speed: 1.0ms preprocess, 48.3ms inference, 1.3ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 45.0ms
# Speed: 1.1ms preprocess, 45.0ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 1 enemy, 39.8ms
# Speed: 1.0ms preprocess, 39.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.09054073625738594 0.09166952194083183
#
# 0: 160x160 1 enemy, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.15447841136732332 -0.017481478642390937
#
# 0: 160x160 1 enemy, 44.7ms
# Speed: 1.0ms preprocess, 44.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
# -0.21828489738197482 0.09001458000397243
#
# 0: 160x160 1 enemy, 45.5ms
# Speed: 1.0ms preprocess, 45.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.1629589749681389 0.12378486516977436
#
# 0: 160x160 1 enemy, 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
# 0.007453088517484921 0.07289497878443513
#
# 0: 160x160 1 enemy, 45.3ms
# Speed: 1.0ms preprocess, 45.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
# -0.07480135278263492 -0.007674338931159034
#
# 0: 160x160 1 enemy, 47.1ms
# Speed: 1.0ms preprocess, 47.1ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.04697877609789074 0.010142385034857258
#
# 0: 160x160 1 enemy, 46.1ms
# Speed: 0.0ms preprocess, 46.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# -0.03559740075212236 0.0030405444942787265
#
# 0: 160x160 2 enemys, 44.8ms
# ...
#
# 0: 160x160 (no detections), 42.2ms
# Speed: 2.1ms preprocess, 42.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 52.5ms
# Speed: 1.4ms preprocess, 52.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.8ms
# Speed: 0.0ms preprocess, 35.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 36.9ms
# Speed: 0.0ms preprocess, 36.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 34.7ms
# Speed: 1.0ms preprocess, 34.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.0ms
# Speed: 1.2ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 36.7ms
# Speed: 1.0ms preprocess, 36.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.1ms
# Speed: 1.0ms preprocess, 35.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 38.8ms
# Speed: 1.0ms preprocess, 38.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.6ms
# Speed: 1.0ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 34.2ms
# Speed: 1.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 35.4ms
# Speed: 0.0ms preprocess, 35.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.4ms
# Speed: 1.0ms preprocess, 46.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 36.0ms
# Speed: 0.0ms preprocess, 36.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 43.6ms
# Speed: 1.0ms preprocess, 43.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 33.1ms
# Speed: 0.0ms preprocess, 33.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 34.8ms
# Speed: 1.0ms preprocess, 34.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 32.3ms
# Speed: 1.0ms preprocess, 32.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 38.0ms
# Speed: 2.0ms preprocess, 38.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 41.5ms
# Speed: 1.4ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 54.7ms
# Speed: 1.2ms preprocess, 54.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 5 enemys, 43.4ms
# Speed: 1.0ms preprocess, 43.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.14412021220504692 0.14656737350928403
#
# 0: 160x160 5 enemys, 49.5ms
# Speed: 0.0ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.14412021220504692 0.14656737350928403
#
# 0: 160x160 (no detections), 68.9ms
# Speed: 1.5ms preprocess, 68.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 52.6ms
# Speed: 0.0ms preprocess, 52.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.3ms
# Speed: 1.4ms preprocess, 46.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 43.1ms
# Speed: 1.2ms preprocess, 43.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 49.1ms
# Speed: 1.5ms preprocess, 49.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 57.8ms
# Speed: 1.1ms preprocess, 57.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 37.7ms
# Speed: 1.0ms preprocess, 37.7ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 86.2ms
# Speed: 19.9ms preprocess, 86.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 54.3ms
# Speed: 1.4ms preprocess, 54.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 44.4ms
# Speed: 1.0ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 38.5ms
# Speed: 2.0ms preprocess, 38.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.1ms
# Speed: 1.0ms preprocess, 46.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 45.0ms
# Speed: 1.0ms preprocess, 45.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 60.0ms
# Speed: 0.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 46.5ms
# Speed: 2.2ms preprocess, 46.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 48.9ms
# Speed: 1.0ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 49.5ms
# Speed: 1.0ms preprocess, 49.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 47.8ms
# Speed: 0.0ms preprocess, 47.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 (no detections), 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 160)
#
# 0: 160x160 5 enemys, 94.1ms
# Speed: 1.5ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.14535853754354464 -0.17804188136327073
#
# 0: 160x160 5 enemys, 51.0ms
# Speed: 0.0ms preprocess, 51.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.18148018769531482 -0.18283968813042184
#
# 0: 160x160 4 enemys, 49.4ms
# Speed: 1.1ms preprocess, 49.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 160)
# 0.16389048509288598 -0.1988873356038342
#
# 0: 160x160 4 enemys, 38.7ms
# Speed: 1.0ms preprocess, 38.7ms inference, 1.4ms postprocess per image at shape (1, 3, 160, 160)
# 0.16389048509288598 -0.1988873356038342
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 while True:
#       3     img = ImageGrab.grab(bbox=bbox)
# ----> 4     results=model(img)
#       5     for r in results:
#       6         if len(r.boxes.xywh)>0:
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\engine\model.py:98, in Model.__call__(self, source, stream, **kwargs)
#      96 def __call__(self, source=None, stream=False, **kwargs):
#      97     """Calls the 'predict' function with given arguments to perform object detection."""
# ---> 98     return self.predict(source, stream, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\engine\model.py:239, in Model.predict(self, source, stream, predictor, **kwargs)
#     237 if prompts and hasattr(self.predictor, 'set_prompts'):  # for SAM-type models
#     238     self.predictor.set_prompts(prompts)
# --> 239 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:198, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     196     return self.stream_inference(source, model, *args, **kwargs)
#     197 else:
# --> 198     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\utils\_contextlib.py:35, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      32 try:
#      33     # Issuing `None` to a generator fires it up
#      34     with ctx_factory():
# ---> 35         response = gen.send(None)
#      37     while True:
#      38         try:
#      39             # Forward the response to our caller and get its next request
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:265, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     263 # Inference
#     264 with profilers[1]:
# --> 265     preds = self.inference(im, *args, **kwargs)
#     267 # Postprocess
#     268 with profilers[2]:
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\engine\predictor.py:137, in BasePredictor.inference(self, im, *args, **kwargs)
#     134 """Runs inference on a given image using the specified model and arguments."""
#     135 visualize = increment_path(self.save_dir / Path(self.batch[0][0]).stem,
#     136                            mkdir=True) if self.args.visualize and (not self.source_type.tensor) else False
# --> 137 return self.model(im, augment=self.args.augment, visualize=visualize)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\autobackend.py:355, in AutoBackend.forward(self, im, augment, visualize)
#     352     im = im.permute(0, 2, 3, 1)  # torch BCHW to numpy BHWC shape(1,320,192,3)
#     354 if self.pt or self.nn_module:  # PyTorch
# --> 355     y = self.model(im, augment=augment, visualize=visualize) if augment or visualize else self.model(im)
#     356 elif self.jit:  # TorchScript
#     357     y = self.model(im)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:42, in BaseModel.forward(self, x, *args, **kwargs)
#      40 if isinstance(x, dict):  # for cases of training and validating while training.
#      41     return self.loss(x, *args, **kwargs)
# ---> 42 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:59, in BaseModel.predict(self, x, profile, visualize, augment)
#      57 if augment:
#      58     return self._predict_augment(x)
# ---> 59 return self._predict_once(x, profile, visualize)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\tasks.py:79, in BaseModel._predict_once(self, x, profile, visualize)
#      77 if profile:
#      78     self._profile_one_layer(m, x, dt)
# ---> 79 x = m(x)  # run
#      80 y.append(x if m.i in self.save else None)  # save output
#      81 if visualize:
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\modules\head.py:59, in Detect.forward(self, x)
#      57 else:
#      58     box, cls = x_cat.split((self.reg_max * 4, self.nc), 1)
# ---> 59 dbox = dist2bbox(self.dfl(box), self.anchors.unsqueeze(0), xywh=True, dim=1) * self.strides
#      61 if self.export and self.format in ('tflite', 'edgetpu'):
#      62     # Normalize xywh with image size to mitigate quantization error of TFLite integer models as done in YOLOv5:
#      63     # https://github.com/ultralytics/yolov5/blob/0c8de3fca4a702f8ff5c435e67f378d1fce70243/models/tf.py#L307-L309
#      64     # See this PR for details: https://github.com/ultralytics/ultralytics/pull/1695
#      65     img_h = shape[2] * self.stride[0]
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File c:\Users\Administator\anaconda3\Lib\site-packages\ultralytics\nn\modules\block.py:33, in DFL.forward(self, x)
#      31 """Applies a transformer layer on input tensor 'x' and returns a tensor."""
#      32 b, c, a = x.shape  # batch, channels, anchors
# ---> 33 return self.conv(x.view(b, 4, self.c1, a).transpose(2, 1).softmax(1)).view(b, 4, a)
#
# KeyboardInterrupt:

# %% [markdown]
# CNN 데이터셋 라벨링 확인용

# %%
# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./images"
lth = "./labels"

# 이미지 목록과 레이블 목록을 생성
img_list = sorted(os.listdir(pth))
lab_list = sorted(os.listdir(lth))

# 이미지와 레이블을 읽음
for i in range(len(img_list)):
    if i ==653:
        continue
    im = cv2.imread(pth + '/' + str(i) + ".jpg")
    with open(lth + '/' + str(i) + ".txt","r") as lbr:
        ll=lbr.read()
        ll=list(ll.split())
    ll=[round(center_size*float(x)) for x in ll]    
    cv2.circle(im, (ll[0],ll[1]), 5, (0,255,0), 2)
    # 텍스트 추가
    cv2.putText(im, str(i), (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # 이미지 출력
    cv2.imshow("chek", im)
    cv2.waitKey(0)

# 모든 창 닫음
cv2.destroyAllWindows()

# %% [markdown]
# canny 필터 적용, canny_path에 변환된 이미지 저장

# %%
canny_path="canny/"
if not osp.isdir(canny_path):
    os.makedirs(canny_path)
# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./images"
lth = "./labels"

# 이미지 목록과 레이블 목록을 생성
img_list = sorted(os.listdir(pth))
lab_list = sorted(os.listdir(lth))

# 이미지와 레이블을 읽음
for i in img_list:
    num = i.find(".")
    im = cv2.imread(pth + '/' + i[:num] + ".jpg")
    im = cv2.resize(im, (center_size,center_size))
    im = cv2.Canny(im, 100, 200)
    cv2.imwrite(canny_path + i[:num] + ".jpg", im)
    with open(lth + '/' + i[:num] + ".txt","r") as lbr:
        ll=lbr.read()
        ll=list(ll.split())
    ll=[round(center_size*float(x)) for x in ll]    
    cv2.circle(im, (ll[0],ll[1]), 5, (255,255,255), 2)
    # 텍스트 추가
    cv2.putText(im, str(i), (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # 이미지 출력
    cv2.imshow("chek", im)
    key=cv2.waitKey(1)
    if key==ord('q'):
        break

# 모든 창 닫음
cv2.destroyAllWindows()

# %% [markdown]
# cnn용으로 만든 라벨들을 yolo라벨로 변환

# %%
cv2.namedWindow('win')
cv2.setMouseCallback("win", mouse_callback)

changed_label_path="yololabel/"
if not osp.isdir(changed_label_path):
    os.makedirs(changed_label_path)

# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./images"
lth = "./labels"

# 이미지 목록과 레이블 목록을 생성
img_list = os.listdir(pth)
lab_list = os.listdir(lth)
changed_lab_list = os.listdir(changed_label_path)

# 이미지와 레이블을 읽음
for i in img_list:

    key=""
    num=i.find(".")
    
    if i[:num]+".txt" not in changed_lab_list:
        while key!=ord(" "):
            img = cv2.imread(pth + '/' + i[:num] + ".jpg")
            img = cv2.resize(img, (center_size,center_size))
            img_temp=img
            #cv2.imwrite(canny_path + i[:num] + ".jpg", im)

            with open(lth + '/' + i[:num] + ".txt","r") as lbr:
                ll=lbr.read()
                ll=list(ll.split())
            ol=ll
            ll=[round(center_size*float(x)) for x in ll]

            cv2.rectangle(img_temp, (ll[0]-size, ll[1]-size), (ll[0]+size, ll[1]+size), (0, 0, 255) if charic_select==True else (255,255,255), 1)
            cv2.putText(img_temp, f" hero : {heroes[hero_num]}", (10, ll[1]), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
            # 텍스트 추가
            cv2.putText(img_temp, str(i), (20, 20), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)
            
            # 이미지 출력
            cv2.imshow("win", img_temp)
            key=cv2.waitKey(1)

            if key == ord("q"):
                break
            elif key == ord("z"):
                if charic_select==True:
                    charic_select=False
                else:
                    charic_select=True
        with open(changed_label_path + '/' + i[:num] + ".txt","w") as lbr:
                lbr.write(f"{hero_num} {ol[0]} {ol[1]} {float(size*2)/center_size} {float(size*2)/center_size}")
    if key==ord('q'):
        break

# 모든 창 닫음
cv2.destroyAllWindows()

# %% [markdown]
# 파일 이름 변환 코드

# %%
# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./imgNlabel/train/images"
lth = "./imgNlabel/train/labels"
img_list = sorted(os.listdir(pth))
lab_list = sorted(os.listdir(lth))

# 이미지 목록과 레이블 목록을 생성
img_list = sorted(os.listdir(pth))

max=len(img_list)
for i in range(max):
    os.rename(pth+ "/" + img_list[i], pth + "/img" +str(i+2898) + ".jpg")
for i in range(max):
    os.rename(lth+ "/" + lab_list[i], lth + "/img" +str(i+2898) + ".txt")

# %% [markdown]
# 임의의 이미지와 라밸 100개를 train에서 test 혹은 valid로 이동시키는 코드

# %%
import shutil
import random

# 이미지 경로와 레이블 경로를 변수로 선언
pth = "./imgNlabel/train/images"
lth = "./imgNlabel/train/labels"

img_list = sorted(os.listdir(pth))
lab_list = sorted(os.listdir(lth))

npth = "C:/Users/Administator/Desktop/새 폴더 (2)/images"
nlth = "C:/Users/Administator/Desktop/새 폴더 (2)/labels"

# 이미지 저장할 폴더 생성
if not osp.isdir(npth):
    os.makedirs(npth)

# 텍스트 파일 저장할 폴더 생성
if not osp.isdir(nlth):
    os.makedirs(nlth)

max=len(img_list)

ran=random.sample(range(0, max), 100)
for i in ran:
    shutil.move(pth+ "/" + img_list[i], npth)
    shutil.move(lth+ "/" + lab_list[i], nlth)

# %% [markdown]
# 클래스를 전부 0으로 바꿔버리기

# %%
# 이미지 경로와 레이블 경로를 변수로 선언
lth = "./imgNlabel/valid/labels"

lab_list = sorted(os.listdir(lth))

for i in lab_list:
    with open(lth + "/" + i, "r") as t:
        txt = t.read()
    txt = txt.split()
    txt[0] = "0"
    with open(lth + '/' + i,"w") as t:
        t.write(f"{txt[0]} {txt[1]} {txt[2]} {txt[3]} {txt[4]}")

# %% [markdown]
# CNN용 xy좌표만

# %%
# 마우스 클릭 좌표 기준 사각형 그리기
def stopped():
    global train_path, count
    global pointlist, while_stop, charic_select, menu
    while_stop=True

    while True:
        key=cv2.waitKey(10)
        tempimg=img.copy()

        # 상태바 & 박스 그리기
        cv2.putText(tempimg, f"{menu}stop count:{count} \n tag : {heroes[hero_num]}", (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0))
        if len(pointlist)>0:
            for point in pointlist:
                cv2.rectangle(tempimg, (point[0]-point[2], point[1]-point[2]), (point[0]+point[2], point[1]+point[2]), (255-point[3]*6, point[3]*6, -abs(6*(point[3]-20))+120))
        cv2.imshow("win",tempimg)

        if key == ord(" "):
            if  len(pointlist)>0:
                count = file_count(train_path)
                text = open_file(label_path + str(count) + ".txt", "w")
                cv2.imwrite(train_path + str(count) + '.jpg', img)
                for point in pointlist:
                    text.write(f"{float(point[0])/center_size} {float(point[1])/center_size}")
                    text.write("\n")
                text.close()
            break

        # 마지막 박스 지우기
        elif key == ord("x"):
            if len(pointlist)>0:
                pointlist.pop()
        # 캐릭터 변경 모드
        elif key == ord("z"):
            charic_select=True
            menu="charic change-"

    #변수 초기화
    while_stop=False
    pointlist=[]
